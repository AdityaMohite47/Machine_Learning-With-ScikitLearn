# %% [markdown]
# <h3> Coding Simple Linear Regression ( Ordinary Least Squares )

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

data = pd.read_csv("./Datasets/Advertising.csv")

# %% [markdown]
# - Generating Total Expense of Advertising ( feature engineering )

# %%
data['Total Expense'] = data['TV'] + data['radio'] + data['newspaper']
data.sample(10)
# Out:
#         TV  radio  newspaper  sales  Total Expense
# 163  163.5   36.8        7.4   18.0          207.7
# 5      8.7   48.9       75.0    7.2          132.6
# 194  149.7   35.6        6.0   17.3          191.3
# 4    180.8   10.8       58.4   12.9          250.0
# 70   199.1   30.6       38.7   18.3          268.4
# 130    0.7   39.6        8.7    1.6           49.0
# 7    120.2   19.6       11.6   13.2          151.4
# 65    69.0    9.3        0.9    9.3           79.2
# 16    67.8   36.6      114.0   12.5          218.4
# 42   293.6   27.7        1.8   20.7          323.1

# %%
sns.scatterplot(x='Total Expense' , y='sales' , data=data)
# Out:
# <Axes: xlabel='Total Expense', ylabel='sales'>

# %%
sns.regplot(x='Total Expense' , y='sales' , data=data)
# Out:
# <Axes: xlabel='Total Expense', ylabel='sales'>

# %%
X = data['Total Expense']
y = data['sales']

# y = B1x + B0
print(np.polyfit(X,y , deg=1)) # gives coeffs B1 and B0 for the equation above
# Out:
# [0.04868788 4.24302822]

# %%
# a simple ordinary least squares for regression
test_expense = np.linspace(0 , 500 , 100)
#       y                        B1             x                B0
prediction = np.polyfit(X,y , deg=1)[0] * test_expense + np.polyfit(X,y , deg=1)[1]

# %%
# plotting predictions vs actual spend
sns.scatterplot(x='Total Expense' , y='sales' , data=data)
plt.plot(test_expense , prediction , color='red')

# %%
# testing 
spend = 359
predicted_sales =  np.polyfit(X,y , deg=1)[0] * spend + np.polyfit(X,y , deg=1)[1]
print(predicted_sales)
# Out:
# 21.72197689157461
